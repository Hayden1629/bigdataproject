# %%
import pandas as pd

demo = pd.read_parquet("data/parquet_recent/demo.parquet")
drug = pd.read_parquet("data/parquet_recent/drug.parquet")
reac = pd.read_parquet("data/parquet_recent/reac.parquet")
outc = pd.read_parquet("data/parquet_recent/outc.parquet")
rpsr = pd.read_parquet("data/parquet_recent/rpsr.parquet")
ther = pd.read_parquet("data/parquet_recent/ther.parquet")
indi = pd.read_parquet("data/parquet_recent/indi.parquet")

# %%
for name, df in {"demo": demo, "drug": drug, "reac": reac, "outc": outc, "rpsr": rpsr, "ther": ther, "indi": indi}.items():
    print(f"duplicates of {name}: {df.duplicated().sum()}")
# Out:
# duplicates of demo: 0
# duplicates of drug: 0
# duplicates of reac: 159536
# duplicates of outc: 0
# duplicates of rpsr: 0
# duplicates of ther: 0
# duplicates of indi: 0

# %%
ther.head()
# Out:
#     primaryid    caseid dsg_drug_seq  start_dt    end_dt   dur dur_cod quarter
# 0   100051542  10005154            1  20120215      None  None    None  2023Q3
# 1  1001678123  10016781            1    201201    201204  None    None  2023Q3
# 2  1001678123  10016781            4  20120327      None  None    None  2023Q3
# 3  1001678123  10016781           10  20121005  20200121  2665     DAY  2023Q3
# 4  1001678123  10016781           12      None  20200121  None    None  2023Q3
